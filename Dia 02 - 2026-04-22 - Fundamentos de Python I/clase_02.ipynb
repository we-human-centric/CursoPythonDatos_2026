# %% [markdown]
# <a href="https://colab.research.google.com/github/we-human-centric/CursoPythonDatos_2026/blob/main/Dia%2002%20-%202026-04-22%20-%20Fundamentos%20de%20Python%20I/clase_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Día 2 · Fundamentos de Python I · Sintaxis y tipos primitivos**Fecha:** Miércoles 22 de abril de 2026  **Módulo:** Módulo 1 · Introducción a Python y kick-off del proyecto  ---

# %% [markdown]
# ## IntroducciónHoy cubrimos los bloques básicos del lenguaje: variables, tipos primitivos (int, float, bool, str), operadores aritméticos, relacionales, lógicos y de pertenencia, y manipulación de strings con f-strings. Al final sabrás leer y escribir programas cortos que resuelven cálculos y manipulan texto.

# %% [markdown]
# ## 1. Variables y tipado dinámicoUna **variable** es un nombre que apunta a un objeto en memoria. En Python se crean al asignar un valor con `=`, sin necesidad de declarar el tipo:```pythonprecio = 30        # enteroproducto = "pan"   # string```Python es de **tipado dinámico**: una misma variable puede apuntar a objetos de tipos distintos en distintos momentos. Esto lo hace flexible pero obliga a ser cuidadoso. El tipo lo lleva el *objeto*, no la *variable*.**Reglas de nombres** (PEP 8):- Solo letras, dígitos y `_`. No pueden empezar por dígito.- Se distinguen mayúsculas y minúsculas (`precio` ≠ `Precio`).- Convención: `snake_case` para variables y funciones; `PascalCase` para clases; `MAYUSCULAS` para constantes.- Nombres descriptivos: `precio_unitario` > `p1`.

# %% [markdown]
# ## Variables y NombresAhora que puedes imprimir cosas con `print` y puedes hacer matemáticas, el siguiente paso es aprender sobre variables. En programación, una variable no es más que un nombre para algo, similar a cómo mi nombre "Juli" es un nombre para "El humano que está hablando sin parar". Los programadores usamos estos nombres de variables para hacer que su código se lea más como inglés o espanglish y porque tienen mala memoria. Si no usaran buenos nombres para las cosas en su software, se perderían cuando intentaran leer su código de nuevo.Si te quedas atascado con este ejercicio, recuerda los trucos que se te han enseñado hasta ahora para encontrar diferencias y centrarte en los detalles:- Escribe un comentario sobre cada línea explicando en inglés qué hace.- Lee tu código Python hacia atrás.Su creacion se realiza a través de la **ASIGNACION** de un **VALOR** a una variable utilizando el operador ```=```.Nombres de Variables:*   Distingue el uso de mayúsculas y minúsculas*   No se permite caracteres de puntuación como +, -, @, $ y %.*   Significativos con relación al dato que  representa o almacena.*   Hay [palabras reservadas](https://es.wikibooks.org/wiki/Python/Generalidades/Palabras_reservadas,_operadores_y_s%C3%ADmbolos_del_lenguaje) que no son válidas como nombres de variables.*   Emplear las recomendaciones de [PEP-8](https://www.python.org/dev/peps/pep-0008/) para seguir mejores prácticas sobre cómo escribir código Python**Buena práctica:** Los nombres de las variables deben estar en minúsculas, con palabras separadas por guiones bajos según sea necesario para mejorar la legibilidad.

# %%
#Diferenciar entre mayúsculas y minúculasprecio = 30Precio = 24Precio = 5555#¿Cuál será el resultado de imprimir Precio?Precio

# %% [markdown]
# ## 2. Tipos primitivos en PythonLos **tipos primitivos** son los bloques básicos. Los que usaremos constantemente:| Tipo | Ejemplo | Uso ||---|---|---|| `int` | `42` | Enteros sin tamaño máximo práctico || `float` | `3.14` | Números con decimales (IEEE 754) || `bool` | `True`, `False` | Verdadero / falso || `str` | `"hola"` | Cadenas de texto (Unicode) || `NoneType` | `None` | Ausencia de valor |**Detalle sobre floats**: `0.1 + 0.2` en Python no es exactamente `0.3` sino `0.30000000000000004`. Esto no es un bug: es una limitación de la representación binaria de decimales. Para dinero se usa el módulo `decimal`; para comparar floats no se usa `==` sino `math.isclose()`.**Tipado opcional**: desde Python 3.5 existen *type hints* que permiten anotar el tipo esperado. No son obligatorios ni verificados en ejecución, pero ayudan a herramientas como `mypy` y a los IDEs.

# %% [markdown]
# # Tipos de datos en Python

# %% [markdown]
# Datos Primitivos en Python:* Numéricos: enteros `int`, decimales-punto flotante `float` y complejos `complex`* Lógicos: booleanos (```True``` y ```False```)* Cadenas de Caracteres: datos estructurados a partir de `str` (texto y palabras). No hay diferencia en el uso de comillas simples y dobles. La comillas triples se emplean para escribir múltiples líneas (párrafos)```type(x)``` es una función de Python que nos permite saber por consola el tipo de dato que es x.

# %%
#NUMERICOS:print(type(-8), type(5.6), type(1-2j), type("hola"))

# %%
#BOOLEANOSprint(type(True), type(False))

# %%
#CADENAS DE CARACTERESprint(type('Palabras'), type("Uso de oraciones"), type('''Se emplea para párrafos. Incluye múltiples oraciones'''))

# %% [markdown]
# **Tipado dinámico:** No necesitas declarar el tipo de una variable antes de usarla. Python determina automáticamente el tipo de datos en tiempo de ejecución.

# %%
x = 5  # x es un enterox = "hello"  # ahora x es una cadena

# %% [markdown]
# **Anotaciones de tipo:** Desde Python 3.5, puedes proporcionar anotaciones de tipo utilizando la sintaxis : después del nombre de la variable o argumento de función, seguido del tipo esperado.

# %%
first_name: str = "Julian"age: int = 39

# %% [markdown]
# La anotación de tipo es simplemente una sugerencia o un tipo esperado, pero el valor real asignado es un flotante debido a la presencia del decimal. Esto no genera un error en Python debido a su naturaleza de tipado dinámico, pero podría ser considerado un error semántico o de lógica dependiendo del contexto del código.

# %%
age: int = "treinta y nueve"

# %% [markdown]
# ## 3. Operadores aritméticosPython incluye los operadores habituales y dos que conviene memorizar:| Operador | Acción | Ejemplo ||---|---|---|| `+ - * /` | Suma, resta, multiplicación, división | `7 / 2 == 3.5` || `//` | División entera (sin decimales) | `7 // 2 == 3` || `%` | Módulo (residuo) | `7 % 2 == 1` || `**` | Potencia | `2 ** 10 == 1024` |El módulo (`%`) es útil para pruebas de paridad (`n % 2 == 0` significa "par") y para operaciones cíclicas.**Precedencia**: como en matemáticas, `** `tiene más precedencia que `*` y `/`, que a su vez tienen más precedencia que `+` y `-`. En caso de duda, pon paréntesis: hacen el código legible.

# %% [markdown]
# # Operadores aritméticos

# %% [markdown]
# Cada lenguaje de programación tiene alguna forma de hacer números y matemáticas. No te preocupes: los programadores frecuentemente mienten sobre ser genios matemáticos cuando realmente no lo son. Si fueran genios matemáticos, estarían haciendo matemáticas, no escribiendo marcos web con errores para poder conducir coches de carreras.Este ejercicio tiene muchos símbolos matemáticos. Vamos a nombrarlos de inmediato para que sepas cómo se llaman. Mientras los tecleas, di el nombre. Cuando decirlos se vuelva aburrido, puedes dejar de decirlos. Aquí están los nombres:- \+ más **SUMA**- \- menos- / barra- \* asterisco- % porcentaje🌶️ Viste cómo faltan las operaciones? Después de teclear el código de este ejercicio, regresa y averigua qué hace cada uno de estos y completa la tabla. Por ejemplo, \+ hace la suma.

# %%
print("Ahora contaré mis gallinas:")print("Gallinas", 25 + 30 / 6)print("Gallos", 100 - 25 * 3 % 7)print("Ahora contaré los huevos:")print(3 + 2 + 1 - 5 + 4 % 2 - 1 / 4 + 6)print("¿Es verdad que 3 + 2 < 5 - 7?")print(3 + 2 < 5 - 7)print("¿Cuánto es 3 + 2?", 3 + 2)print("¿Cuánto es 5 - 7?", 5 - 7)print("Oh, por eso es Falso.")print("¿Qué tal algo más?")print("¿Es mayor?", 5 > -2)print("¿Es mayor o igual?", 5 >= -2)print("¿Es menor o igual?", 5 <= -2)

# %%
# Ejecutar diferentes tipos de operaciones en los datosa = 5 ** 5print(a)

# %% [markdown]
# ## 🌶️ Ejercicio 1 · Titanic (cálculo de porcentajes)

# %% [markdown]
# # 🌶️ EJERCICIO 1:Cuando revisamos los datos del accidente del Titanic tenemos algunos datos:- Había 891 pasajeros a bordo del Titanic (total),- 342 pasajeros sobrevivieron (survived)- 113 pasajeros eran menores de 18 años (minors)En la siguiente celda de código, reemplace los subrayados (____) con código para calcular los valores de dos variables más:- *survived_fraction* debe establecerse en la fracción de pasajeros que sobrevivieron al desastre del Titanic.- *minors_fraction* debe ser la fracción de pasajeros que eran menores de edad (menores de 18 años).Para cada variable, su respuesta debe ser un número entre 0 y 1.

# %%
total = ____survived = ____survived_fraction = ____# Print the value of the variableprint(survived_fraction)# TODO: Fill in the value of the minors_fraction variableminors_fraction = ____# Print the value of the variableprint(minors_fraction)

# %% [markdown]
# ## 4. Operadores relacionales y lógicosLos **operadores relacionales** (`==`, `!=`, `<`, `<=`, `>`, `>=`) comparan dos valores y devuelven un booleano. Ojo: `=` asigna, `==` compara. Confundirlos es un error clásico.Los **operadores lógicos** combinan booleanos:- `and` — verdadero si ambos lo son (conjunción).- `or` — verdadero si al menos uno lo es (disyunción).- `not` — niega el valor.Python evalúa en **corto circuito**: en `a and b`, si `a` es falso, `b` ni siquiera se evalúa. Esto se explota para escribir código defensivo como `if obj is not None and obj.valor > 0:`.**Operadores de pertenencia** (`in`, `not in`) permiten preguntar si un elemento está dentro de una colección: `"a" in "hola"` es `True`.

# %% [markdown]
# # Operadores Relacionales y lógicos* Operadores **RELACIONALES**: Comparan valores y devuelven un booleano (```True``` o ```False```) según corresponda el resultado de la evaluación.

# %%
a = 9 # Almacena el valor 9 en aa == 8 # Confirmame si a es igual a 8

# %%
a=4b=18print("mayor que:", a > b)print("menor que:", a < b)

# %%
a, b = 1, 5print("mayor o igual que:", b >= a)    # 5 >= 1print("menor o igual que:", -1 <= a)   # -1 <= 1

# %%
# ¿Es verdadera esta expresión?5 > 3 > 1

# %%
# ¿Es verdadera esta expresión?5 > 3 < 4 == 3 + 1

# %% [markdown]
# # Operadores **LÓGICOS**:Permiten construir expresiones lógicas. El resultado es un booleano.>NOTA: Revisa [tablas de verdad](https://es.wikipedia.org/wiki/Tabla_de_verdad) para las operaciones de conjunción, disyunción y negación.

# %%
# CONJUNCION (and)a = 4a >= 1 and a <= 5   #(4>=1)  and  (4<=5)  = True

# %%
# DISYUNCION (or)a = 7a >= 6 or a == 10   #(7>=6) or (a==10) = True

# %%
# NEGACION (not)a = Falsenot a

# %% [markdown]
# **Lista de símbolos comunes que puede usar para construir condiciones.**---<table><tbody><tr><th><b>Symbol</b></th><th><b>Meaning</b></th></tr><tr><td>==</td><td>equals</td></tr><tr><td>!=</td><td>does not equal</td></tr><tr><td>&#60;</td><td>less than</td></tr><tr><td>&#60;=</td><td>less than or equal to</td></tr><tr><td>&#62;</td><td>greater than</td></tr><tr><td>&#62;=</td><td>greater than or equal to</td></tr></tbody></table>**💡Nota importante**: cuando verifique que dos valores sean iguales, asegúrese de usar el signo == y no el signo =.- `var_one==1` comprueba si el valor de `var_one` es 1, pero- `var_one=1` establece el valor de `var_one` en 1.

# %% [markdown]
# # Operadores de **PERTENENCIA**:Permiten evidenciar si un objeto forma parte o no de una secuencia. El resultado es un booleano.

# %%
texto = "La escritura en Python es intuitiva"# SE ENCUENTRA (in)print('N' in texto)# NO SE ENCUENTRA (not in)print('x' not in texto)

# %% [markdown]
# ## ⚠️ Prioridad de Operadores:**Nota** Cuando se utilizan varios operadores en una sola expresión, la precedencia de los operadores determina qué partes de la expresión se evalúan y en qué orden. Los operadores con mayor precedencia se evalúan primero. Los operadores con la misma precedencia se evalúan de izquierda a derecha.Orden de los operadores:- () parentheses, for grouping- ** exponent- *, / multiplication and division- +, - addition and subtraction- ==, !=, <, <=, >, >= comparisonsEn resumen:1.   Parentesis2.   Potencia3.  Multiplicación y división4.  Suma y resta5. Comparaciones

# %%
y = -1 + 2 * 0 - (24 / 2 ** 3)print(y)

# %% [markdown]
# ## 5. Strings · representación de textoLas cadenas (`str`) son secuencias **inmutables** de caracteres Unicode. Eso significa que una vez creadas no se modifican: las operaciones que "cambian" un string en realidad devuelven uno nuevo.Las cadenas se indexan desde `0` y soportan **slicing** (`s[a:b:paso]`). Los índices negativos cuentan desde el final (`s[-1]` es el último carácter).### f-strings (desde Python 3.6)La forma moderna de componer texto con variables:```pythonnombre = "Ana"edad = 30print(f"{nombre} tiene {edad} años")```Dentro de las llaves se puede poner cualquier expresión Python, no solo nombres: `f"{2 + 2}"`, `f"{precio * 1.12:.2f}"`, `f"{fecha:%Y-%m-%d}"`. Las f-strings son legibles, rápidas y permiten formateo (decimales, padding, fechas).

# %% [markdown]
# # **Strings en Python**

# %% [markdown]
# **Cadenas:**El tipo str en Python se refiere a las cadenas de caracteres, que son secuencias de caracteres Unicode. Las cadenas en Python pueden contener letras, números, símbolos y caracteres especiales, y se utilizan para representar texto.

# %% [markdown]
# **Índices y slicing o rebanadas:** Los strings se comportan como listas, puedes hacerles slicing. Puedes acceder a caracteres individuales en una cadena utilizando índices y puedes obtener subcadenas utilizando slicing. Esto veremos despues en listas.

# %%
cadena = "Hola"cadena[0]

# %%
cadena[3]

# %% [markdown]
# **Inmutable:** Las cadenas en Python son objetos inmutables, lo que significa que una vez que se crea una cadena, no se puede modificar. Si necesitas modificar una cadena, debes crear una nueva.```pythoncadena = "Hola"# Esto generaría un error, ya que las cadenas son inmutablescadena[0] = 'h'```

# %% [markdown]
# **Concatenación:** Puedes concatenar cadenas utilizando el operador +.

# %%
saludo = "Hola"nombre = "Mundo"saludo_completo = saludo + " " + nombreprint(saludo_completo)

# %% [markdown]
# **Formato de cadena:** Python ofrece varias formas de formatear cadenas, incluyendo el método format() y las f-strings (cadenas f)

# %%
nombre = "Juan"edad = 30print("Hola, mi nombre es {} y tengo {} años.".format(nombre, edad))

# %% [markdown]
# **Cadena multilínea:** Puedes crear cadenas multilínea utilizando comillas triples (""" o ''').

# %%
poema = """En un lugar de la Mancha,de cuyo nombre no quiero acordarme,no ha mucho tiempo que vivía un hidalgo..."""print(poema)

# %% [markdown]
# **Las f-strings** son una característica introducida en Python 3.6 que te permite insertar valores de variables directamente dentro de una cadena de una manera muy legible y concisa.

# %%
nombre = "Mundo"saludo = f"Hola {nombre}!"print(saludo)

# %%
# Puedes incluir cualquier expresión Python válida dentro de las llaves {}.numero = 42saludo = f"El doble de {numero} es {numero * 2}."print(saludo)

# %%
# Puedes incluir expresiones matemáticas simplesa = 10b = 5resultado = f"La suma de {a} y {b} es {a + b}, y su resta es {a - b}."print(resultado)

# %%
# Puedes redondear números dentro de una f-string utilizando la función round().pi = 3.14159265358979323846resultado = f"El valor de pi redondeado a dos decimales es {round(pi, 2)}."print(resultado)

# %%
# Puedes utilizar cadenas de formato dentro de f-stringsprecio = 99.9595resultado = f"El precio es ${precio:.2f}."print(resultado)

# %% [markdown]
# ## 🌶️ Ejercicios con strings

# %% [markdown]
# # 🌶️ EJERCICIO 2.1Una empresa de transporte tiene un número determinado de coches, conductores y pasajeros a transportar en un día. Necesitas calcular cuántos autos no serán conducidos, la capacidad total de transporte para el día y el promedio de pasajeros por autos.Datos Iniciales:*   cars = 100 (Número total de coches)*   space_in_a_car = 4.0 (Espacio disponible en un coche)*   drivers = 30 (Número total de conductores)*   passengers = 90 (Número total de pasajeros)**Calcula y asigna los valores a las siguientes variables:***   cars_not_driven: Número de coches que no se conducirán.*   cars_driven: Número de coches que se conducirán (igual al número de conductores).*   carpool_capacity: Capacidad total de transporte para el día.*   average_passengers_per_car: Promedio de pasajeros por coche.

# %%
cars = 100space_in_a_car = 4.0drivers = 30passengers = 90# haz los calculosprint("Hay", cars, "autos disponibles.")print("Solo hay", drivers, "conductores disponibles.")#print("Habrá", cars_not_driven, "coches vacíos hoy.")#print("Podemos transportar", carpool_capacity, "personas hoy.")#print("Tenemos", passengers, "para compartir el coche hoy.")#print("Necesitamos poner aproximadamente", average_passengers_per_car,"en cada autos.")

# %% [markdown]
# # 🌶️ EJERCICIO 2.2Realizar las siguientes ejecuciones de código, cree una celda para cada pregunta:1. Imprimir el tipo de dato que es x2. Verificar que el valor de x sea mayor igual a 0 y menor igual a 103. Evaluar si x es diferente a 44. Dividir x para el valor de 2 (obtener el cociente)5. Cree una variable llamada _carname_ y asígnele el valor Volvo6. Muestre en pantalla el contenido de la variable _carname_

# %%
# Ejercicio 2x = 3print('X es de tipo:', type(x))

# %% [markdown]
# # Más Variables e ImpresiónLas cadenas son realmente útiles, así que en este ejercicio aprenderás a hacer cadenas que tienen variables incrustadas en ellas. Incrustas variables dentro de una cadena usando una secuencia especial de {} y luego pones la variable que quieres dentro de los caracteres {}. También debes comenzar la cadena con la letra f para "formato", como en f"Hola {somevar}". Esta pequeña f antes de las "(comillas dobles) y los caracteres {} le dicen a Python 3: "Oye, esta cadena necesita ser formateada. Pon estas variables ahí".

# %%
nombre = 'Julián'edad = 40 # no es mentiraaltura = 175 # cmpeso = 80 # kilosojos = 'Oscuros'cabello = 'Marrón'print(f"Hablemos sobre {nombre}.")print(f"Él mide {altura} pulgadas de alto.")print(f"Pesa {peso} libras.")print("En realidad eso no es demasiado pesado.")print(f"Tiene ojos {ojos} y cabello {cabello}.")

# %%
# esta línea es complicada, trata de hacerla exactamente bientotal = edad + altura + pesoprint(f"Si sumo {edad}, {altura} y {peso} obtengo {total}.")

# %% [markdown]
# # 🌶️ EJERCICIO 2.3- Crea variables para almacenar una altura en pulgadas (altura_pulgadas) y un peso en libras (peso_libras). Puedes asignarles valores numéricos directamente.- Utiliza fórmulas para convertir altura_pulgadas a centímetros y peso_libras a kilogramos.- Imprime los resultados de las conversiones en un formato legible, como "X pulgadas son Y centímetros" y "X libras son Y kilogramos".

# %%
#

# %% [markdown]
# ## 6. Input del usuarioLa función `input()` lee texto desde la consola. Siempre devuelve un `str`, aunque el usuario escriba un número. Para usarlo como número hay que convertirlo con `int(...)` o `float(...)`.En notebooks, `input()` abre una caja para escribir en la parte superior de la interfaz.

# %% [markdown]
# ## Preguntando a las PersonasAhora es el momento de acelerar el ritmo. Has estado haciendo muchas impresiones para familiarizarte con escribir cosas simples, pero esas cosas simples son bastante aburridas. Lo que queremos hacer ahora es obtener datos en tus programas. Esto es un poco complicado porque tienes que aprender a hacer dos cosas que pueden no tener sentido de inmediato, pero confía en mí y hazlo de todos modos. Tendrá sentido en unos pocos ejercicios.La mayor parte de lo que hace el software es lo siguiente:1. Tomar algún tipo de entrada de una persona.2. Cambiarla.3. Imprimir algo para mostrar cómo cambió.Hasta ahora has estado imprimiendo cadenas, pero no has podido obtener ninguna entrada de una persona. Puede que ni siquiera sepas qué significa "entrada", pero escribe este código de todos modos y hazlo exactamente igual. En el próximo ejercicio haremos más para explicar la entrada.```pythonprint("¿Cuántos años tienes?", end=' ')edad = input()print("¿Cuánto mides?", end=' ')altura = input()print("¿Cuánto pesas?", end=' ')peso = input()print(f"Entonces, tienes {edad} años, mides {altura} y pesas {peso}.")```

# %%
print("¿Cuántos años tienes?", end=' ')edad = input()

# %% [markdown]
# ## 7. Cierre · qué deberías poder responderAl final del día, deberías poder contestar sin mirar:- ¿Qué significa que Python sea de tipado dinámico?- ¿Cuándo usar `//` y cuándo `/`?- ¿Por qué `0.1 + 0.2 != 0.3`?- ¿Qué hace el corto circuito en `and` y `or`?- ¿Cómo se escribe una f-string con 2 decimales?Si alguna no está clara, relee la sección correspondiente antes de la clase de mañana.

# %% [markdown]
# ---## 🧑‍🤝‍🧑 Trabajo en grupo sobre el caso- Abran el dataset de su caso con `pandas.read_csv` (solo explorar las primeras filas).- Identifiquen en el dataset: una variable numérica continua, una categórica y un texto.- Escriban un script Python que imprima un resumen con f-strings: `"El dataset tiene {n} filas y {k} columnas"`.

# %% [markdown]
# ## 📦 Entregable del díaScript `resumen_dataset.py` con el resumen por f-string, compartido en el repo del grupo.

# %% [markdown]
# ---## 📚 Lecturas adicionalesPara profundizar después de la clase, en [`Lecturas.md`](./Lecturas.md) encontrarás una curaduría de artículos técnicos y de negocios en español (4 por día), con copia local en la subcarpeta [`lecturas/`](./lecturas/) cuando la fuente lo permite.### 🎬 Video recomendado<iframe width="720" height="405" src="https://www.youtube.com/embed/u4I9PqhqCo8" title="Curso Python · Sintaxis básica II: tipos, operadores y variables (Vídeo 4)" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>**[Curso Python · Sintaxis básica II: tipos, operadores y variables (Vídeo 4)](https://www.youtube.com/watch?v=u4I9PqhqCo8)** · Píldoras Informáticas_Explicación clara en español sobre tipos primitivos, operadores aritméticos/lógicos y reglas de nombrado de variables. Canal con una comunidad hispanohablante enorme en programación._
