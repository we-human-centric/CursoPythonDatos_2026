# %% [markdown]
# <a href="https://colab.research.google.com/github/we-human-centric/CursoPythonDatos_2026/blob/main/Dia%2004%20-%202026-04-24%20-%20Planteamiento%20del%20proyecto/clase_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Cerramos la primera semana montando la estructura profesional del proyecto. Un proyecto de datos bien planteado ahorra semanas de trabajo; uno mal planteado se descarrila en la fase de modelado. Hoy es el día para definirlo bien.
#
# Este cuaderno es una *plantilla*. Tu equipo la rellena con los datos, la pregunta y el contexto del caso que elegiste.

# %% [markdown]
# > **Hoy haces** · Llenar la plantilla del proyecto: pregunta de negocio, 10–15 historias de usuario y ficha del dataset. Es la S1 — el resto del curso se apoya en esto. ~2h30.
# >
# > **Entrega** · **ENTREGA S1 — Definición del Problema.** Pregunta + historias de usuario + ficha del dataset + repo base con README completo, antes de la medianoche del viernes 24 de abril.

# %%
import pandas as pd
import numpy as np

SEED = 42
np.random.seed(SEED)

print("Setup para entrega S1 completado ✓")

# %% [markdown]
# ## Información del equipo
#
# **Nombre del proyecto:** [RELLENA CON EL NOMBRE]
#
# **Integrantes:**
# - Nombre 1 (Data Lead / Model Lead / Product Lead)
# - Nombre 2
# - Nombre 3
#
# **Caso elegido:** [RELLENA CON EL NOMBRE DEL CASO]
#
# **Repositorio GitHub:** [ENLACE]
#
# **Fecha de entrega:** 24 de abril, 2026

# %% [markdown]
# ## Pregunta de negocio
#
# ¿Cuál es la pregunta que tu equipo va a responder con los datos?
#
# Debe ser:
# - Específica (no "entender el dataset", sino "¿qué clientes están en riesgo de abandonar?")
# - Respondible con los datos disponibles
# - Relevante para alguien (usuario, negocio, comunidad)
#
# **Tu pregunta:**
#
# [RELLENA AQUÍ]

# %% [markdown]
# ## Justificación
#
# ¿Por qué esta pregunta importa? ¿A quién le sirve la respuesta?
#
# Escribe 2-3 párrafos (máximo media página) que justifiquen por qué vale la pena responder esto.
#
# [RELLENA AQUÍ]

# %% [markdown]
# ## Carga del dataset
#
# Aquí verificamos que el dataset se carga y entendemos su forma básica.

# %%
# Carga el dataset. Ajusta la URL o ruta según corresponda.
# Usamos sns.load_dataset para datasets públicos, o pd.read_csv() para URLs

# Opción 1: desde seaborn
# df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# Opción 2: dataset local o URL
# df = pd.read_csv('datos/dataset.csv')

# Para esta plantilla, usamos un dataset de ejemplo
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv')

print(f"Dataset cargado: {df.shape[0]} registros, {df.shape[1]} columnas")

# %%
# Primeras filas
df.head()

# %%
# Información sobre columnas, tipos, nulos
df.info()

# %%
# Estadísticas descriptivas
df.describe()

# %%
# Conteo de nulos
print("Valores nulos por columna:")
print(df.isnull().sum())

# %% [markdown]
# ## Ficha del dataset
#
# Completa esta sección con los detalles de tu dataset.

# %% [markdown]
# **Origen:** [URL o descripción de dónde viene]
#
# **Licencia:** [Si tiene, indica; si es público, indica "Público"]
#
# **Fecha de extracción:** 24 de abril, 2026
#
# **Número de registros:** [RELLENA]
#
# **Número de columnas:** [RELLENA]
#
# ### Columnas
#
# | Columna | Tipo | Descripción | % Nulos |
# |---------|------|-------------|----------|
# | [nombre] | [int/float/str] | [Descripción breve] | [%] |
# | | | | |
#
# ### Limitaciones conocidas
#
# - [Limitación 1: ej. Datos solo de cierto período, cierta región, etc.]
# - [Limitación 2: ej. Nulos en columna X, sesgos en muestreo, etc.]
# - [Limitación 3]
#
# ### Preguntas pendientes
#
# - ¿Hay más información que no está en el dataset que nos ayudaría?
# - ¿Qué variables no tenemos pero necesitaríamos para responder la pregunta?

# %% [markdown]
# ## Historias de usuario
#
# Narra el caso desde la perspectiva de los usuarios/stakeholders. Formato:
#
# **Como [rol], quiero [acción] para [beneficio].**
#
# Ejemplos:
# - Como gerente de ventas, quiero identificar qué clientes están en riesgo de cancelar, para contactarlos con una oferta especial.
# - Como biólogo marino, quiero entender la relación entre temperatura y reproducción de peces, para predecir cambios poblacionales.
#
# **Rellena al menos 10-15 historias para tu caso:**
#
# 1. [RELLENA]
# 2. [RELLENA]
# 3. [RELLENA]
# ...
# 15. [RELLENA]

# %% [markdown]
# > **Recordatorio** · **ENTREGA S1 hoy.** Antes de medianoche del viernes 24 de abril en el repo del equipo.

# %% [markdown]
# ## Próximos pasos
#
# Semana 2: Análisis exploratorio detallado (EDA).
# Semana 3: Modelado y validación.
# Semana 4: Visualización y comunicación de resultados.
#
# ---
#
# **Esta plantilla se entrega hoy. Durante el fin de semana, ajusta según el feedback del docente.**
